# %%
# GRADIENT BOOSTING
# Aprende de sus propios errores y los va corrigiendo en cada iteracion
# Es una combinacion de varios arboles de decision (debilmente correlacionados
    # Empieza con un modelo simple (suele ser una prediccion promedio)
    # calcula los errores(residuos del modelo inicial)
    # crea un nuevo arbol(aprende a predecir los errores del modelo anterior)
    # se suma al modelo anterior(corriege al modelo anterior y agrega un peso pequeño -> learning rate)
    # Repite el proceso por un numero definido de iteraciones o hasta que no haya mejora

import matplotlib.pyplot as plt
import matplotlib.image as npimg

img = npimg.imread('../../img/gradient_boosting.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1023.5), np.float64(1535.5), np.float64(-0.5))

# %%
# parametros importantes
# n_estimators == numero de arboles a crear
# learning_rate == peso que se le da a cada arbol nuevo (que tanto corrige cada arbol los errores del anterior)
# max_depth == profundidad maxima de cada arbol (controla el sobreajuste)

# LO MALO => puede ser sensible a datos ruidosos y outliers, mas lento de entrenar comparado con otros modelos

# SESGO == UNDERFITTING
# VARIANZA == OVERFITTING

# TEST
# ¿Cuál es la idea principal de Gradient Boosting? == c) Entrenar modelos en secuencia corrigiendo errores previos

# Una diferencia clave entre Random Forest y Gradient Boosting es que: == c) Gradient Boosting entrena modelos dependientes

# Los árboles usados en Gradient Boosting suelen ser: == b) Árboles débiles y poco profundos

# ¿Para qué sirve el learning_rate? == c) Controla cuánto corrige cada árbol

# Gradient Boosting puede sobreajustar si: == c) Los árboles son muy profundos

# Gradient Boosting entrena todos los árboles al mismo tiempo. == Falso

# ¿En qué tipo de problemas Gradient Boosting suele destacar más? == c) Problemas con datos tabulares y estructurados

# Gradient Boosting aprende de los ________ del modelo anterior. == errores

# %%
# XGBoost -> Versión optimizada de Gradient Boosting == Más rápido, Regularización incluida, Maneja mejor overfitting, Muy usado en Kaggle
# Light GBM -> Otro algoritmo basado en Gradient Boosting == Más rápido que XGBoost, Maneja grandes volúmenes de datos, Usa histogramas para dividir datos

img = npimg.imread('../../img/comparacion1.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(2767.5), np.float64(1247.5), np.float64(-0.5))

# %%
img = npimg.imread('../../img/comparacion2.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(2625.5), np.float64(1128.5), np.float64(-0.5))
