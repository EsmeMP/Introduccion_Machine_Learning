# %%
import pandas as pd
import matplotlib.pyplot as plt

# metricas obtenidas en el modelo de regresion lineal -> peor que predicir sin datos
metricas_rl = {
    'Modelo': 'Regresión Lineal',
    'RMSE': 2.23,
    'MAE': 1.89,
    'R²': -0.03
}
# metricas en el arbol de decision 
metricas_arbol = {
    'Modelo': 'Árbol de Decisión',
    'RMSE': 0.93,
    'MAE': 0.70,
    'R²': 0.82
}

# comparacion
df_comparacion = pd.DataFrame([metricas_rl, metricas_arbol])
display(df_comparacion)
# Out:
#               Modelo  RMSE   MAE    R²
# 0   Regresión Lineal  2.23  1.89 -0.03
# 1  Árbol de Decisión  0.93  0.70  0.82
